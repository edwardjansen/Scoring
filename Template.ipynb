# %%
# import display libs
from IPython.display import Image
# %matplotlib inline
from IPython.display import Latex

# %%
# import libs
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt


# setup figure params
figureparams = {'axes.labelsize': 24,
           'axes.titlesize': 20,
           'axes.linewidth': 1.3,
           'font.size': 20,
           'legend.fontsize': 18,
           'figure.figsize': (10,7),
           'font.family': 'serif',
           'font.serif': 'Computer Modern Roman',
           'xtick.labelsize': 18,
           'xtick.major.size': 5.5,
           'xtick.major.width': 1.3,
           'ytick.labelsize': 18,
           'ytick.major.size': 5.5,
           'ytick.major.width': 1.3,
           'text.usetex': True,
           'figure.autolayout': True}
plt.rcParams.update(figureparams)
matplotlib.rcParams['text.usetex']=False # might have to install proper libs to set this to true?
matplotlib.rcParams['text.latex.unicode']=True
matplotlib.get_configdir()

# %% [markdown]
# # Title: this is a markdown cell with a single #
# ### Contents: this has 3 #s
#     1. Section1: this is normal text
#     2. Section2
#     3. Section3
#         a. Subsection3a
#         b. Subsection3b
#     4. Maybe there is even a Section4

# %% [markdown]
# ## Section1: 2 #s

# %%
# this is a code cell which you execute with Shift+Enter
a = 1 + 1
b = 2 + 3
print(a*b-a+5*b)
# Out:
# 33

# %% [markdown]
# ## Section2

# %% [markdown]
# Some Text
#
# Make sure you regularly save your jupyter project (Ctrl + S), as the browser does not give you a warning that the file is not saved if you close it.

# %% [markdown]
# ## Section 3
# Some text in between.
#
# You can write $LaTeX$ here in the usual way (with $s), but text.usetex doesn't recognize all LateX commands, so sometimes you'll have to improvise.
#
# For example, writing an equation works fine:
# \begin{equation}
# E = mc^2,
# \end{equation}
# but using e.g. smth like $\text{ \begin{align} }$ might cause problems:
# \begin{align}
# E &= mc^2, \\
# F &\neq ma.
# \end{align}
# However, it might also work. This is actually not a bug, but a feature that makes life @ jupyter notebooks more interesting.
#
#
# #### Subsection 3a: 4 #s
